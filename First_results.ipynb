# %% [markdown]
# ## Analyse des scripts de l'étudiant

# %%
# Affichage du code contenu dans Menus.py
with open('/Users/Gance/Downloads/paris/Menus.py', 'r') as file:
    print(file.read())
# Out:
# # On veut tester cela :
#
# # Compter le nombre de plats dans chaque catégorie (ex. nombre d'entrées, plats, desserts).
# # Comparer les restaurants avec beaucoup de choix vs. ceux avec un menu réduit.
# # Croiser ces infos avec la note moyenne (reviewSummary.rating) pour voir s’il y a une corrélation entre le nombre de plats et la qualité perçue.
#
# ##Hypothèse :
# #"Un menu avec moins de plats est-il mieux noté, car il est plus centré sur la qualité (fait maison) ?""
# #%%
# import json
# import matplotlib.pyplot as plt
# import numpy as np
# import seaborn as sns
#
# #%%
# # Ouvrir et lire le fichier JSON dont il est question.
# # Rappel : c'est le fichier qui regroupe tous les menus des 2717 restaurants parisiens étudiés.
# with open("/Users/valentinletour/Documents/Paris Saclay/M1.2/Mémoire/paris_bis/paris_menus_rewiews_.json", "r", encoding="utf-8") as file:
#     paris_menus_reviews = json.load(file)
#
# #%%
# ...

# %% [markdown]
# On veut tester cela :
#
# Compter le nombre de plats dans chaque catégorie (ex. nombre d'entrées, plats, desserts).
# Comparer les restaurants avec beaucoup de choix vs. ceux avec un menu réduit.
# Croiser ces infos avec la note moyenne (reviewSummary.rating) pour voir s’il y a une corrélation entre le nombre de plats et la qualité perçue.
#
# ### Hypothèse :
# "Un menu avec moins de plats est-il mieux noté, car il est plus centré sur la qualité (fait maison) ?""
# %%

# %%
# Lecture de Fait_Maison_Analyse_tex.py
with open('/Users/Gance/Downloads/paris/Fait_Maison_Analyse_tex.py', 'r') as file:
    print(file.read())
# Out:
# #%%
# ##############################################
# ##############################################
# ############################# Maintenant, on va s'essayer à une analyse sémantique des commentaires
#
# #%%
# # Le fichier json "restaurants_compiles" est trop lourd de je vais essayer de filtrer pour ne garder que des informations utiles.
# # En consultant mon notebook, je choisis de ne garder que ça pour le moment :
# #data.locations.keywords
# #data.locations.locationId
# #data.locations.name
# #data.locations.placeType
# #data.locations.url
# #data.locations.topicCount
# #data.locations.reviewSummary.alertStatusCount
# #data.locations.reviewSummary.rating
# #data.locations.reviewSummary.count
# #data.locations.reviewAggregations.ratingCounts
# #data.locations.reviewAggregations.languageCounts
#
# ## Ajout par rapport à avant :
# #data.locations.reviewListPage.totalCount
# #data.locations.reviewListPage.reviews
# #data.locations.reviewListPage.reviews.title
# ...
